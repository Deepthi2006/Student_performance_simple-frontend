# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepthi2006/Student_performance_simple-frontend/blob/main/students_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv("/content/Student_Performance.csv")
d.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
d.dropna(inplace=True)
d.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
# making x and y
x=d.drop("Performance Index",axis=1)
y=d["Performance Index"]
# encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x["Extracurricular Activities"]=le.fit_transform(x["Extracurricular Activities"])

# train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
# fit linear regression model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
# accuracy
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9889558863295086

# %%
import pickle
with open('model.pkl','wb') as f:
  pickle.dump(model,f)

from google.colab import files
files.download('model.pkl')
